# %% [markdown]
# ## Basic Plots

# %%
# importing required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# going with some basic plots
x = np.linspace(0, 10, 50)
sinus = np.sin(x)
print (x, len(x))
print (sinus, len(sinus))
# Out:
# [ 0.          0.20408163  0.40816327  0.6122449   0.81632653  1.02040816
#   1.2244898   1.42857143  1.63265306  1.83673469  2.04081633  2.24489796
#   2.44897959  2.65306122  2.85714286  3.06122449  3.26530612  3.46938776
#   3.67346939  3.87755102  4.08163265  4.28571429  4.48979592  4.69387755
#   4.89795918  5.10204082  5.30612245  5.51020408  5.71428571  5.91836735
#   6.12244898  6.32653061  6.53061224  6.73469388  6.93877551  7.14285714
#   7.34693878  7.55102041  7.75510204  7.95918367  8.16326531  8.36734694
#   8.57142857  8.7755102   8.97959184  9.18367347  9.3877551   9.59183673
#   9.79591837 10.        ] 50
# [ 0.          0.20266794  0.39692415  0.57470604  0.72863478  0.85232157
#   0.94063279  0.98990308  0.99808748  0.96484631  0.89155923  0.78126802
#   0.63855032  0.46932961  0.2806294   0.08028167 -0.12339814 -0.32195632
#  -0.50715171 -0.67129779 -0.80758169 -0.91034694 -0.97532829 -0.99982867
# ...

# %%
plt.plot(x, sinus)
plt.show()

# %%
plt.plot(x, sinus, "o")
plt.show()

# %%
plt.plot(x, sinus, "--")
plt.show()

# %%
plt.plot(x, sinus, "-")
plt.show()

# %%
plt.plot(x, sinus, "*")
plt.show()

# %%
# rapid multiplot
cosinus = np.cos(x)
# plt.plot(x, sinus, "-b", x, sinus, "ob", x, cosinus, "-r", x, cosinus, "or")
plt.plot(x, sinus, "-b", x, sinus, "or", x, cosinus, "-r", x, cosinus, "ob")
# plt.plot(x, sinus, "or", x, sinus, "-b", x, cosinus, "ob", x, cosinus, "-r")
plt.xlabel("Plotting x-values...")
plt.ylabel("Plotting y-values...")
plt.title("Example of Multiplot...")
plt.show()

# %%
# step by step
plt.plot(x, sinus, label ='Sinus', color = "blue", linestyle = '--', linewidth = 2)
plt.plot(x, cosinus, label = 'Cosinus', color = 'red', linestyle = '-', linewidth = 2)
plt.xlabel("Plotting x-values...")
plt.ylabel("Plotting y-values...")
plt.title("This is the graph title...")
plt.legend(loc = 0)
plt.show()

# %% [raw]
# Class Assignment:
# =================
# Considering equation of a circle as: x ** 2 + y ** 2 = r ** 2
# Draw/Plot a circle with radius 10.

# %%
# x ** 2 + y ** 2 = r ** 2
r = 10
x = np.linspace(-10, 10, 100)
y = np.sqrt(r ** 2 - x ** 2)
plt.figure(figsize = (4, 4))
plt.plot(x, y, "-r")
plt.plot(x, -y, "-r")
plt.show()

# %%
x=np.linspace(-10,10,50)
r=10
y=np.sqrt(r**2-x**2)
plt.figure(figsize = (4, 4))
plt.plot(x,y,'--g',x,-y,'--g')
plt.show()

# %% [markdown]
# ### Scatter (2D) plots

# %%
try:
    salary = pd.read_csv("e:\\datafile\\salary_table.csv")
    print (salary.head())
except:
    print ("File access error !!!")
# Out:
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
salary.head()
# Out:
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
df = salary.copy()
df.head()
# Out:
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
colors = colors_edu = {"Bachelor":"red", "Master":"green", "Ph.D":"blue"}
print (colors_edu)
plt.scatter(df['experience'], df['salary'], c = df['education'].apply(lambda x: colors_edu[x]))
plt.xlabel("Experience of the employee in years...")
plt.ylabel("Salary in INR...")
plt.title("Experience vs. Salary...")
plt.show()
# Out:
# {'Bachelor': 'red', 'Master': 'green', 'Ph.D': 'blue'}

# %% [markdown]
# ### Group by on dataset

# %%
# group by education x management will generate 6 groups
for values, data in salary.groupby(['education', 'management']):
    print ("Values:", values)
    print (data)
# Out:
# Values: ('Bachelor', 'N')
#     salary  experience education management
# 7    10535           2  Bachelor          N
# 13   11417           4  Bachelor          N
# 20   12336           6  Bachelor          N
# 28   13548           8  Bachelor          N
# 29   14467          10  Bachelor          N
# 34   14861          11  Bachelor          N
# 37   15990          13  Bachelor          N
# 43   17483          16  Bachelor          N
# 45   19346          20  Bachelor          N
# Values: ('Bachelor', 'Y')
#     salary  experience education management
# 0    13876           1  Bachelor          Y
# 10   14975           3  Bachelor          Y
# 19   15965           5  Bachelor          Y
# 24   16978           7  Bachelor          Y
# 26   17404           8  Bachelor          Y
# Values: ('Master', 'N')
#     salary  experience education management
# 3    11283           1    Master          N
# 6    11772           2    Master          N
# ...

# %%
# Define colors / symbols manually
symbols_manage = {'Y':'*', 'N':'.'}
colors_edu = {'Bachelor':'red', 'Master':'green', 'Ph.D':'blue'}

plt.figure(figsize = (6, 5))

for values, data in salary.groupby(['education', 'management']):
    edu, manager = values
    plt.scatter(data['experience'], data['salary'], marker=symbols_manage[manager],
                color = colors_edu[edu], s = 150, label = manager + " / " + edu)
plt.legend()
plt.xlabel("Experience in years...")
plt.ylabel("Salary in INR...")
plt.title("Plotting Experience vs. Salary...")
plt.show()

# %% [markdown]
# ### Saving Figures

# %%
# saving in the bitmap format
plt.plot(x, sinus)
plt.savefig("sinus.png")
plt.show()

# %%
# saving in the .svg format
plt.plot(x, sinus)
plt.savefig('sinus.svg')
plt.show()

# %%
# saving in the PDF format
plt.plot(x, sinus)
plt.savefig('sinus.pdf')
plt.close()

# %% [markdown]
# ### Exploring data (with seaborn)

# %%
# importing required modules
import seaborn as sns

# %%
sns.boxplot(x='education', y='salary', hue='management', data=salary, palette="PRGn")
# Out:
# <AxesSubplot:xlabel='education', ylabel='salary'>

# %%
help(sns.boxplot)

# %%
sns.boxplot(x='salary', y='education', hue='management', data=salary, palette="PRGn")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='education'>

# %%
sns.boxplot(x="management", y="salary", hue="education", data=salary, palette="PRGn")
# Out:
# <AxesSubplot:xlabel='management', ylabel='salary'>

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 10, 0.01)

ax1 = plt.subplot(211)
ax1.plot(t, np.sin(2*np.pi*t))

ax2 = plt.subplot(212, sharex=ax1)
ax2.plot(t, np.sin(4*np.pi*t))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = ax1.boxplot(all_data,
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
ax1.set_title('Rectangular box plot')

# notch shape box plot
bplot2 = ax2.boxplot(all_data,
                     notch=True,  # notch shape
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
ax2.set_title('Notched box plot')

# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adding horizontal grid lines
for ax in [ax1, ax2]:
    ax.yaxis.grid(True)
    ax.set_xlabel('Three separate samples')
    ax.set_ylabel('Observed values')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>
